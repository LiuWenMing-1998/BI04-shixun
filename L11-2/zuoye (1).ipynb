# %%
import pickle
with open('data.kpl','rb') as file:
    train_data=pickle.load(file)

# %%
train_data
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
import numpy as np
train_data['fraud']=np.where(train_data['Order Status']=='SUSPECTED_FRAUD',1,0)

# %%
train_data['fraud']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 180514    0
# 180515    0
# 180516    0
# 180517    0
# 180518    0
# Name: fraud, Length: 180519, dtype: int64

# %%
train_data['fraud'].sum()
# Out:
# 4062

# %%
train_data['Delivery Status'].value_counts()
# Out:
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: Delivery Status, dtype: int64

# %%
train_data['late_delivery']=np.where(train_data['Delivery Status']=='Late delivery',1,0)

# %%
train_data['late_delivery']
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 180514    0
# 180515    1
# 180516    1
# 180517    0
# 180518    0
# Name: late_delivery, Length: 180519, dtype: int64

# %%
categorical_cols=train_data.select_dtypes(include='object').columns
categorical_cols
# Out:
# Index(['Type', 'Delivery Status', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Department Name', 'Market',
#        'Order City', 'Order Country', 'Order Region', 'Order State',
#        'Order Status', 'Product Image', 'Product Name',
#        'shipping date (DateOrders)', 'Shipping Mode', 'CustomerFull Name'],
#       dtype='object')

# %%
train_data.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
train_data.drop(['Customer Email','Customer Password','Product Description','Product Status','Product Image','Customer Lname','Customer Fname'],axis=1,inplace=True)

# %%
len(train_data.columns)
# Out:
# 54

# %%
#根据热力图继续删除字段
train_data.drop(['Order Customer Id','Order Item Cardprod Id','Order Item Id','Order Item Total','Order Profit Per Order','Product Card Id','order_month_year','Product Category Id','Product Price'],axis=1,inplace=True)

# %%
len(train_data.columns)
# Out:
# 45

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
train_data
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
train_data.drop(['Customer Zipcode'],axis=1,inplace=True)

# %%
train_data.drop(['shipping date (DateOrders)','Sales per customer','Latitude','Longitude','Customer Street'],axis=1,inplace=True)

# %%
train_data.drop(['order date (DateOrders)'],axis=1,inplace=True)

# %%
train_data.drop(['Delivery Status','Late_delivery_risk','Order State'],axis=1,inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Category Id                    180519 non-null  int64
#  5   Category Name                  180519 non-null  object
#  6   Customer City                  180519 non-null  object
#  7   Customer Country               180519 non-null  object
#  8   Customer Id                    180519 non-null  int64
#  9   Customer Segment               180519 non-null  object
#  10  Customer State                 180519 non-null  object
#  11  Department Id                  180519 non-null  int64
# ...

# %%
categorical_cols=train_data.select_dtypes(include='object').columns
categorical_cols
# Out:
# Index(['Type', 'Category Name', 'Customer City', 'Customer Country',
#        'Customer Segment', 'Customer State', 'Department Name', 'Market',
#        'Order City', 'Order Country', 'Order Region', 'Order Status',
#        'Product Name', 'Shipping Mode', 'CustomerFull Name'],
#       dtype='object')

# %%
train_data=train_data.dropna(subset=['CustomerFull Name'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for cat in categorical_cols:
    train_data[cat]=le.fit_transform(train_data[cat])
train_data[categorical_cols]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Type  Category Name  Customer City  Customer Country  \
# 0          1             40             66                 1
# 1          3             40             66                 1
# 2          0             40            452                 0
# 3          1             40            285                 0
# 4          2             40             66                 1
# ...      ...            ...            ...               ...
# 180514     0             18             59                 0
# 180515     1             18             26                 0
# 180516     3             18             55                 0
# ...

# %%
#得到所有的数值类型
numerical_cols=train_data.columns.tolist()
for x in categorical_cols.tolist():
    numerical_cols.remove(x)
numerical_cols
# Out:
# ['Days for shipping (real)',
#  'Days for shipment (scheduled)',
#  'Benefit per order',
#  'Category Id',
#  'Customer Id',
#  'Department Id',
#  'Order Id',
#  'Order Item Discount',
#  'Order Item Discount Rate',
#  'Order Item Product Price',
#  'Order Item Profit Ratio',
#  'Order Item Quantity',
#  'Sales',
#  'Order Zipcode',
#  'order_year',
#  'order_month',
#  'order_week_day',
#  'order_hour',
#  'fraud',
#  'late_delivery']

# %%
x_fraud=train_data.loc[:,train_data.columns!='fraud']
y_fraud=train_data['fraud']
x_fraud
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          1                         3                              4
# 1          3                         5                              4
# 2          0                         4                              4
# 3          1                         3                              4
# 4          2                         2                              4
# ...      ...                       ...                            ...
# 180514     0                         4                              4
# 180515     1                         3                              2
# 180516     3                         5                              4
# 180517     2                         3                              4
# 180518     2                         4                              4
#
#         Benefit per order  Category Id  Category Name  Customer City  \
# ...

# %%
x_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180511 entries, 0 to 180518
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180511 non-null  int64
#  1   Days for shipping (real)       180511 non-null  int64
#  2   Days for shipment (scheduled)  180511 non-null  int64
#  3   Benefit per order              180511 non-null  float64
#  4   Category Id                    180511 non-null  int64
#  5   Category Name                  180511 non-null  int64
#  6   Customer City                  180511 non-null  int64
#  7   Customer Country               180511 non-null  int64
#  8   Customer Id                    180511 non-null  int64
#  9   Customer Segment               180511 non-null  int64
#  10  Customer State                 180511 non-null  int64
#  11  Department Id                  180511 non-null  int64
# ...

# %%
y_fraud
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 180514    0
# 180515    0
# 180516    0
# 180517    0
# 180518    0
# Name: fraud, Length: 180511, dtype: int64

# %%
x_late=train_data.loc[:,train_data.columns!='late_delivery']
y_late=train_data['late_delivery']
x_late
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          1                         3                              4
# 1          3                         5                              4
# 2          0                         4                              4
# 3          1                         3                              4
# 4          2                         2                              4
# ...      ...                       ...                            ...
# 180514     0                         4                              4
# 180515     1                         3                              2
# 180516     3                         5                              4
# 180517     2                         3                              4
# 180518     2                         4                              4
#
#         Benefit per order  Category Id  Category Name  Customer City  \
# ...

# %%
y_late
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 180514    0
# 180515    1
# 180516    1
# 180517    0
# 180518    0
# Name: late_delivery, Length: 180511, dtype: int64

# %%
#数据集切分
from sklearn.model_selection import train_test_split
x_fraud_train,x_fraud_test,y_fraud_train,y_fraud_test=train_test_split(x_fraud,y_fraud,test_size=0.2)
x_late_train,x_late_test,y_late_train,y_late_test=train_test_split(x_late,y_late,test_size=0.2)

# %%
x_fraud_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144408 entries, 163721 to 33294
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           144408 non-null  int64
#  1   Days for shipping (real)       144408 non-null  int64
#  2   Days for shipment (scheduled)  144408 non-null  int64
#  3   Benefit per order              144408 non-null  float64
#  4   Category Id                    144408 non-null  int64
#  5   Category Name                  144408 non-null  int64
#  6   Customer City                  144408 non-null  int64
#  7   Customer Country               144408 non-null  int64
#  8   Customer Id                    144408 non-null  int64
#  9   Customer Segment               144408 non-null  int64
#  10  Customer State                 144408 non-null  int64
#  11  Department Id                  144408 non-null  int64
# ...

# %%
#数据规范化
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_fraud_train=sc.fit_transform(x_fraud_train)
x_fraud_test=sc.transform(x_fraud_test)
x_late_train=sc.fit_transform(x_late_train)
x_late_test=sc.transform(x_late_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,roc_auc_score,confusion_matrix,f1_score
def model_stats(model ,x_train, x_test, y_train, y_test, name='Fraud'):
    model=model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    accurancy=accuracy_score(y_pred,y_test)
    recall=recall_score(y_pred,y_test)
    auc=roc_auc_score(y_pred,y_test)
    f1=f1_score(y_pred,y_test)
    confusion=confusion_matrix(y_pred,y_test)
    print('Model use',model)
    print('{} Accurancy : {}%'.format(name,accurancy*100))
    print('{} recall : {}%'.format(name,recall*100))
    print('{} auc : {}%'.format(name,auc*100))
    print('{} f1 : {}%'.format(name,f1*100))
    print('{} confusion : {}'.format(name,confusion*100))
    return accurancy,recall,f1

# %%
# 逻辑回归模型
from sklearn.linear_model import LogisticRegression
model_fraud=LogisticRegression()
model_late=LogisticRegression()

# %%
model_stats(model_fraud,x_fraud_train,x_fraud_test,y_fraud_train,y_fraud_test,'Fraud')
# Out:
# Model use LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Fraud Accurancy : 100.0%
# Fraud recall : 100.0%
# Fraud auc : 100.0%
# Fraud f1 : 100.0%
# Fraud confusion : [[3526300       0]
#  [      0   84000]]
# (1.0, 1.0, 1.0)

# %%
model_stats(model_late,x_late_train,x_late_test,y_late_train,y_late_test,'Late')
# Out:
# Model use LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Late Accurancy : 99.86427720688032%
# Late recall : 99.75213718448074%
# Late auc : 99.87606859224037%
# Late f1 : 99.87591481171971%
# Late confusion : [[1633400       0]
#  [   4900 1972000]]
# (0.9986427720688031, 0.9975213718448075, 0.9987591481171971)

# %%
x_sales=train_data.loc[:,train_data.columns!='Sales']
y_sales=train_data['Sales']

# %%
x_quantity=train_data.loc[:,train_data.columns!='Order Item Quantity']
y_quantity=train_data['Order Item Quantity']

# %%
x_sales_train,x_sales_test,y_sales_train,y_sales_test=train_test_split(x_sales,y_sales,test_size=0.2)
x_quantity_train,x_quantity_test,y_quantity_train,y_quantity_test=train_test_split(x_quantity,y_quantity,test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
def refression_model_stats(model,x_train,x_test,y_train,y_test,model_name='Sales'):
    model=model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print('Model Used',model)
    mae=mean_absolute_error(y_test,y_pred)
    mse=mean_squared_error(y_test,y_pred)
    print('{}MSE{}'.format(model_name,mse))
    print('{}MAE{}'.format(model_name,mae))

# %%
from sklearn.linear_model import LinearRegression
model_sales=LinearRegression()
model_quantity=LinearRegression()

# %%
refression_model_stats(model_sales,x_sales_train,x_sales_test,y_sales_train,y_sales_test,model_name='Sales')
# Out:
# Model Used LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# SalesMSE942.3249579381661
# SalesMAE18.368918260025495

# %%
refression_model_stats(model_quantity,x_quantity_train,x_quantity_test,y_quantity_train,y_quantity_test,model_name='Quantity')
# Out:
# Model Used LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# QuantityMSE0.28105477799589795
# QuantityMAE0.3476422607464495
